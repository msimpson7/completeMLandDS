# %%
import pandas as pd

# %% [markdown]
# # 2 main datatypes

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %% [markdown]
# # series = 1-dimensional

# %%
colors = pd.Series(['Red','Blue','White'])

# %%
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %% [markdown]
# # Dataframe = 2-dimensional

# %%
car_data = pd.DataFrame({"Car make": series, "Color": colors})

# %%
car_data
# Out:
#   Car make  Color
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %% [markdown]
# # Import data

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Exporting a dataframe

# %%
car_sales.to_csv("exported_car_sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Function
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'], index=[0,3,9,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
# .loc refers to index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# Google: "How to convert object to int in pandas"

# %%
car_sales['Price'] = car_sales['Price'].replace('[\$\,\.]', '', regex=True).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6200
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6200
# 9  nissan  White          31600      4   9700

# %%
car_sales['Make'] = car_sales['Make'].str.capitalize()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     Bmw  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6200
# 9  Nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

#New column called seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     Bmw  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    NaN
# 6   Honda   Blue          45698      4   7500    NaN
# 7   Honda   Blue          54738      4   7000    NaN
# 8  Toyota  White          60000      4   6200    NaN
# 9  Nissan  White          31600      4   9700    NaN

# %%
car_sales['Seats'].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     Bmw  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   7000    5.0
# 8  Toyota  White          60000      4   6200    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %%
# Column for Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 5.3, 7.8, 9.3, 4.7, 8.8]
car_sales['Fuel per 100KM'] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 9  Nissan  White          31600      4   9700    5.0             8.8

# %%
car_sales['Total fuel used'] = car_sales['Odometer (KM)']/100 * car_sales['Fuel per 100KM']
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 9  Nissan  White          31600      4   9700    5.0             8.8
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         5258.289
# 6         3564.444
# 7         5090.634
# 8         2820.000
# ...

# %%
# Create a column from a single value
car_sales['Number of wheels'] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 9  Nissan  White          31600      4   9700    5.0             8.8
#
#    Total fuel used  Passed Road Test  Number of wheels
# 0        11253.225              True                 4
# 1         8086.708              True                 4
# ...

# %%
car_sales['Passed Road Test'] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 9  Nissan  White          31600      4   9700    5.0             8.8
#
#    Total fuel used  Numbner of wheels  Passed Road Test
# 0        11253.225                  4              True
# 1         8086.708                  4              True
# ...

# %%
car_sales.drop('Numbner of wheels', axis=1, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 9  Nissan  White          31600      4   9700    5.0             8.8
#
#    Total fuel used  Passed Road Test  Number of wheels
# 0        11253.225              True                 4
# 1         8086.708              True                 4
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 9  Nissan  White          31600      4   9700    5.0             8.8
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
#
#    Total fuel used  Passed Road Test  Number of wheels
# 5         5258.289              True                 4
# 9         2780.800              True                 4
# ...

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 1   Honda    Red          87899      4   5000    5.0             9.2
#
#    Total fuel used  Passed Road Test  Number of wheels
# 5         5258.289              True                 4
# 1         8086.708              True                 4

# %%
# Google: Pandas reset_index
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  Green          99213      4   4500    5.0             5.3
# 1  Nissan  White          31600      4   9700    5.0             8.8
# 2  Toyota  White         150043      4   4000    5.0             7.5
# 3  Toyota   Blue          32549      3   7000    5.0             5.0
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5   Honda    Red          87899      4   5000    5.0             9.2
# 6  Toyota  White          60000      4   6200    5.0             4.7
# 7     Bmw  Black          11179      5  22000    5.0             9.6
# 8   Honda   Blue          54738      4   7000    5.0             9.3
# 9   Honda   Blue          45698      4   7500    5.0             7.8
#
#    Total fuel used  Passed Road Test  Number of wheels
# 0         5258.289              True                 4
# 1         2780.800              True                 4
# ...

# %%
# Apply function to a column
# Convert odometer to miles
car_sales['Odometer (Mi)'] = car_sales['Odometer (KM)'].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0             7.5
# 1   Honda    Red          87899      4   5000    5.0             9.2
# 2  Toyota   Blue          32549      3   7000    5.0             5.0
# 3     Bmw  Black          11179      5  22000    5.0             9.6
# 4  Nissan  White         213095      4   3500    5.0             8.7
# 5  Toyota  Green          99213      4   4500    5.0             5.3
# 6   Honda   Blue          45698      4   7500    5.0             7.8
# 7   Honda   Blue          54738      4   7000    5.0             9.3
# 8  Toyota  White          60000      4   6200    5.0             4.7
# 9  Nissan  White          31600      4   9700    5.0             8.8
#
#    Total fuel used  Passed Road Test  Number of wheels  Odometer (Mi)
# 0        11253.225              True                 4      93776.875
# ...
